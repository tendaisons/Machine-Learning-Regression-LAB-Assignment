# %%
# QUESTION 2:Multiple Regression

import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# Generate a random dataset with 50 samples
np.random.seed(42)
age = np.random.randint(20, 60, 50)
income = np.random.randint(30000, 100000, 50)
education = np.random.randint(10, 20, 50)
spending_habits = 1000 + 10*age + 0.5*income + 20*education + np.random.normal(0, 50, 50)

# Display all rows of the dataset
print(data)


# Create a DataFrame to store the dataset
data = pd.DataFrame({'Age': age, 'Income': income, 'Education': education, 'Spending Habits': spending_habits})

# Features and target variable
X = data[['Age', 'Income', 'Education']]
y = data['Spending Habits']

# Fit the multiple linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Evaluate the model
r2 = r2_score(y, y_pred)

# Print the coefficients
coefficients = dict(zip(X.columns, model.coef_))
print('Coefficients:', coefficients)

# Print the R-squared value
print('R-squared:', r2)



# Plotting the actual spending habits vs. predicted spending habits
plt.figure(figsize=(8, 6))
plt.scatter(y, y_pred, color='blue', label='Actual vs. Predicted')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--', label='Perfect Prediction')
plt.xlabel('Actual Spending Habits')
plt.ylabel('Predicted Spending Habits')
plt.title('Actual vs. Predicted Spending Habits')
plt.legend()
plt.grid(True)
plt.show()


print("""INTERPRETATION OF RESULTS

Coefficients:

For every one-unit increase in Age, the predicted Spending Habits increase by approximately 10.36 units, holding Income and Education constant.
Similarly, a one-unit increase in Income leads to an increase of about 0.50 units in the predicted Spending Habits, keeping Age and Education constant.
Lastly, a one-unit increase in Education results in an increase of around 20.70 units in the predicted Spending Habits, assuming Age and Income remain constant.

R-squared Value:

The R-squared value of approximately 0.99998 indicates that the model explains almost all of the variance in the Spending Habits based on the Age, Income, and Education features.
This high R-squared value suggests that the model fits the data extremely well, with very little variability left unexplained""")


#NOTES
#We generate a random dataset with 50 samples for age, income, education level, and spending habits.
#We create a DataFrame to store the dataset.
#We define the features (age, income, education) and the target variable (spending habits).
#We fit a multiple linear regression model using scikit-learn's LinearRegression.
#We make predictions, evaluate the model using R-squared, and print the coefficients of the features.
#The coefficients indicate the impact of each feature on the person's spending habits.
#You can further analyze the significance of each feature by examining the coefficients. A higher coefficient suggests a stronger impact on spending habits.
# Out:
#     Age  Income  Education  Spending Habits
# 0    58   97121         12     50403.146816
# 1    48   99479         10     51411.196955
# 2    34   49457         12     26319.246942
# 3    27   96557         14     49727.384253
# 4    40   82995         12     43090.347160
# 5    58   70757         10     37228.697937
# 6    38   39692         14     21505.072460
# 7    42   75758         19     39595.324769
# 8    30   95697         16     49414.873408
# 9    30   67065         16     35102.870691
# 10   43   62606         18     33098.117384
# 11   55   41534         19     22675.369536
# 12   59   70397         19     37135.540885
# 13   43   31016         12     17178.196865
# 14   22   85591         16     44359.387705
# 15   41   53247         10     28220.548568
# 16   21   54300         13     28591.264540
# 17   43   39268         13     21302.925089
# 18   49   42185         14     22879.491048
# 19   57   93704         16     48741.630993
# ...
