# %%
# QUESTION 1:Linear Regression
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt


# Set the random seed for reproducibility
np.random.seed(42)

# Generate the number of hours studied (X) with a range of 1 to 10
hours_studied = np.random.uniform(1, 10, 50)

# Generate the corresponding exam scores (Y) using a linear relationship with noise
true_coefficient = 5
true_intercept = 20
noise = np.random.normal(0, 5, 50)
exam_scores = true_intercept + true_coefficient * hours_studied + noise

# Create a DataFrame to store the dataset
dataset = pd.DataFrame({'Hours Studied': hours_studied, 'Exam Scores': exam_scores})

# Display all rows of the dataset
print(dataset)


# Assuming 'dataset' is the DataFrame containing your data
X = dataset[['Hours Studied']]  # Features (number of hours studied)
y = dataset['Exam Scores']     # Target variable (exam scores)

# Fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Evaluate the model
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print the coefficients
print('Intercept:', model.intercept_)
print('Coefficient:', model.coef_[0])

# Print the evaluation metrics
print('Mean Squared Error:', mse)
print('R-squared:', r2)

# Plot the regression line
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red', linewidth=2)
plt.xlabel('Hours Studied')
plt.ylabel('Exam Scores')
plt.title('Linear Regression - Hours Studied vs Exam Scores')
plt.show()
# Out:
#     Hours Studied  Exam Scores
# 0        4.370861    45.546638
# 1        9.556429    68.638985
# 2        7.587945    57.361486
# 3        6.387926    50.434113
# 4        2.404168    24.628229
# 5        2.403951    28.420532
# 6        1.522753    25.310569
# 7        8.795585    69.263538
# 8        6.410035    53.768267
# 9        7.372653    48.048065
# 10       1.185260    27.546722
# 11       9.729189    66.720532
# 12       8.491984    59.075309
# 13       2.911052    37.613641
# 14       2.636425    38.337121
# 15       2.650641    37.909604
# 16       3.738180    34.494813
# 17       5.722808    47.067978
# 18       4.887505    46.093843
# 19       3.621062    42.983037
# 20       6.506676    50.137509
# 21       2.255445    30.348929
# 22       3.629302    32.614834
# 23       4.297257    35.505250
# 24       5.104630    49.585778
# 25       8.066584    67.114118
# 26       2.797064    33.625270
# 27       5.628110    53.158214
# 28       6.331731    53.466836
# ...

# %%
# QUESTION 1: RESULTS INTERPRETATION

print("""QUESTION 1: RESULTS INTERPRETATION

Based on the Values Obtained

1. Intercept: 20.607576370203812:
   - The intercept value obtained from the model is approximately 20.61. This represents the estimated exam score when the number of hours studied is zero.

2. Coefficient: 4.875870002140616:
   - The coefficient value obtained from the model is approximately 4.88. This indicates that for every additional hour studied, the exam score is estimated to increase by around 4.88 units.

3. Mean Squared Error: 20.576778593717194:
   - The Mean Squared Error (MSE) calculated from the model is approximately 20.58. This represents the average squared difference between the predicted exam scores and the actual exam scores in the dataset.

4. R-squared: 0.8844451017669195:
   - The R-squared value obtained from the model is approximately 0.88. This indicates that around 88.44% of the variance in the exam scores can be explained by the number of hours studied in the linear regression model.

Overall, based on the evaluation metrics obtained from the model:
- The intercept and coefficient values suggest that the model estimates the relationship between hours studied and exam scores.
- The low MSE indicates that the model's predictions are relatively close to the actual exam scores.
- The high R-squared value suggests that a significant proportion of the variability in exam scores can be explained by the number of hours studied in the linear regression model.

The scatter plot with the regression line visualizes how the model fits the data, showing the relationship between hours studied and exam scores.
""")

#NOTES
#We separate the features ('Hours Studied') and the target variable ('Exam Scores') from the dataset.
#We fit a linear regression model to the data using LinearRegression() from scikit-learn.
#We make predictions using the fitted model.
#We evaluate the model using mean squared error and R-squared.
#We print the intercept and coefficient of the linear regression model.
#We plot the data points and the regression line.
# Out:
# QUESTION 1: RESULTS INTERPRETATION
#
# Based on the Values Obtained
#
# 1. Intercept: 20.607576370203812:
#    - The intercept value obtained from the model is approximately 20.61. This represents the estimated exam score when the number of hours studied is zero.
#
# 2. Coefficient: 4.875870002140616:
#    - The coefficient value obtained from the model is approximately 4.88. This indicates that for every additional hour studied, the exam score is estimated to increase by around 4.88 units.
#
# 3. Mean Squared Error: 20.576778593717194:
#    - The Mean Squared Error (MSE) calculated from the model is approximately 20.58. This represents the average squared difference between the predicted exam scores and the actual exam scores in the dataset.
#
# 4. R-squared: 0.8844451017669195:
# ...

# %%
# QUESTION 2:Multiple Regression

import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# Generate a random dataset with 50 samples
np.random.seed(42)
age = np.random.randint(20, 60, 50)
income = np.random.randint(30000, 100000, 50)
education = np.random.randint(10, 20, 50)
spending_habits = 1000 + 10*age + 0.5*income + 20*education + np.random.normal(0, 50, 50)

# Display all rows of the dataset
print(data)


# Create a DataFrame to store the dataset
data = pd.DataFrame({'Age': age, 'Income': income, 'Education': education, 'Spending Habits': spending_habits})

# Features and target variable
X = data[['Age', 'Income', 'Education']]
y = data['Spending Habits']

# Fit the multiple linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Evaluate the model
r2 = r2_score(y, y_pred)

# Print the coefficients
coefficients = dict(zip(X.columns, model.coef_))
print('Coefficients:', coefficients)

# Print the R-squared value
print('R-squared:', r2)



# Plotting the actual spending habits vs. predicted spending habits
plt.figure(figsize=(8, 6))
plt.scatter(y, y_pred, color='blue', label='Actual vs. Predicted')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--', label='Perfect Prediction')
plt.xlabel('Actual Spending Habits')
plt.ylabel('Predicted Spending Habits')
plt.title('Actual vs. Predicted Spending Habits')
plt.legend()
plt.grid(True)
plt.show()


print("""INTERPRETATION OF RESULTS

Coefficients:

For every one-unit increase in Age, the predicted Spending Habits increase by approximately 10.36 units, holding Income and Education constant.
Similarly, a one-unit increase in Income leads to an increase of about 0.50 units in the predicted Spending Habits, keeping Age and Education constant.
Lastly, a one-unit increase in Education results in an increase of around 20.70 units in the predicted Spending Habits, assuming Age and Income remain constant.

R-squared Value:

The R-squared value of approximately 0.99998 indicates that the model explains almost all of the variance in the Spending Habits based on the Age, Income, and Education features.
This high R-squared value suggests that the model fits the data extremely well, with very little variability left unexplained""")


#NOTES
#We generate a random dataset with 50 samples for age, income, education level, and spending habits.
#We create a DataFrame to store the dataset.
#We define the features (age, income, education) and the target variable (spending habits).
#We fit a multiple linear regression model using scikit-learn's LinearRegression.
#We make predictions, evaluate the model using R-squared, and print the coefficients of the features.
#The coefficients indicate the impact of each feature on the person's spending habits.
#You can further analyze the significance of each feature by examining the coefficients. A higher coefficient suggests a stronger impact on spending habits.
# Out:
#      Miles_Commute  Public_Transport_Usage
# 0        14.363503               30.163525
# 1        28.767858               16.229068
# 2        23.299849               19.802346
# 3        19.966462               17.165789
# 4         8.900466               32.157228
# 5         8.899863               39.109801
# 6         6.452090               33.720699
# 7        26.654404               19.175688
# 8        20.027875               25.855388
# 9        22.701814               13.601400
# 10        5.514612               33.162409
# 11       29.247746               12.897742
# 12       25.811066               10.710702
# 13       10.308478               40.726365
# 14        9.545624               27.709425
# 15        9.585113               23.749797
# 16       12.606056               31.117134
# 17       18.118911               23.056537
# 18       15.798625               23.749797
# 19       12.280729               34.693157
# 20       20.296322               14.217414
# ...

# %%
# QUESTION 3:Polynomial Regression

import numpy as np
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

np.random.seed(42)
temperature = np.random.uniform(20, 40, 50)
ice_cream_sales = 100 + 3*temperature**2 + np.random.normal(0, 50, 50)

poly_data = pd.DataFrame({'Temperature': temperature, 'Ice Cream Sales': ice_cream_sales})

# Display all rows of the dataset
print(poly_data)

print(""""

Fit polynomial regression models with different degrees:""")


X = poly_data[['Temperature']]
y = poly_data['Ice Cream Sales']

degrees = [2, 3, 4, 5]
best_model = None
best_degree = None
best_r2 = -1
best_mse = float('inf')

for degree in degrees:
    poly_features = PolynomialFeatures(degree=degree)
    X_poly = poly_features.fit_transform(X)
    
    model = LinearRegression()
    model.fit(X_poly, y)
    
    y_pred = model.predict(X_poly)
    
    r2 = r2_score(y, y_pred)
    mse = mean_squared_error(y, y_pred)
    
    print(f'Degree {degree} - R-squared: {r2}, MSE: {mse}')
    
    if r2 > best_r2:
        best_r2 = r2
        best_mse = mse
        best_model = model
        best_degree = degree

print(f'Best model: Degree {best_degree}, R-squared: {best_r2}, MSE: {best_mse}')

# PLOT 

import matplotlib.pyplot as plt

# Scatter plot of the actual data points
plt.figure(figsize=(10, 6))
plt.scatter(poly_data['Temperature'], poly_data['Ice Cream Sales'], color='blue', label='Actual Data')

# Plot the polynomial regression curve for the best model
X_plot = np.linspace(poly_data['Temperature'].min(), poly_data['Temperature'].max(), 100).reshape(-1, 1)
X_plot_poly = PolynomialFeatures(degree=best_degree).fit_transform(X_plot)
y_plot = best_model.predict(X_plot_poly)

plt.plot(X_plot, y_plot, color='red', label=f'Polynomial Regression (Degree {best_degree})')

plt.xlabel('Temperature')
plt.ylabel('Ice Cream Sales')
plt.title('Polynomial Regression Model for Ice Cream Sales Prediction')
plt.legend()
plt.grid(True)
plt.show()


print("""
Discussing the trade-offs involved:

1.Underfitting: Lower-degree polynomial models may underfit the data and fail to capture the non-linear patterns, leading to high bias.

2.Overfitting: Higher-degree polynomial models may overfit the data, capturing noise in the training data and performing poorly on unseen data, leading to high variance.

3.Model Complexity: Increasing the degree of the polynomial increases model complexity, which can lead to overfitting.

4.Interpretability: Higher-degree polynomials are less interpretable compared to lower-degree polynomials.

5.Computational Cost: Higher-degree polynomials require more computational resources and time to train.

By experimenting with different polynomial degrees and evaluating model performance, we can choose the best trade-off between bias and variance. The selected model should generalize well to new data without overfitting or underfitting.""")


print("""

INTERPRETATION OF RESULTS
The results show the performance metrics (R-squared and Mean Squared Error) of polynomial regression models with different degrees fitted to the dataset of temperature and ice cream sales. Here's how you can interpret the results:

1.R-squared (Coefficient of Determination):

R-squared measures the proportion of the variance in the dependent variable (ice cream sales) that is predictable from the independent variable (temperature) in the model.
The R-squared values are very high for all polynomial models (close to 1), indicating that the models explain a large percentage of the variance in the ice cream sales data.
A higher R-squared value suggests that the model fits the data well and captures the underlying relationship between temperature and ice cream sales.

2.Mean Squared Error (MSE):

MSE quantifies the average squared difference between the actual and predicted values in the model.
The MSE values decrease as the degree of the polynomial increases, indicating better model performance in capturing the data's variability.
A lower MSE indicates that the model's predictions are closer to the actual data points, reflecting better model accuracy.

3.Best Model Selection:

The best model is chosen based on both R-squared and MSE values. In this case, the model with a degree of 5 has the highest R-squared value (0.9981) and the lowest MSE (1959.81), indicating the best overall performance among the tested models.
Degree 5 polynomial model captures the underlying relationship between temperature and ice cream sales with the highest accuracy and the least error compared to other polynomial models.""")
# Out:
#     Temperature  Ice Cream Sales
# 0     27.490802      2404.155975
# 1     39.014286      4674.911980
# 2     34.639879      3693.981203
# 3     31.973170      3151.795554
# 4     23.120373      1629.728817
# 5     23.119890      1667.595787
# 6     21.161672      1420.417178
# 7     37.323523      4331.992200
# 8     32.022300      3193.464051
# 9     34.161452      3512.862309
# 10    20.411690      1366.115450
# 11    39.398197      4737.399677
# 12    36.648853      4095.569138
# 13    24.246782      1894.303158
# 14    23.636499      1827.602280
# 15    23.668090      1827.099487
# 16    26.084845      2099.296518
# 17    30.495129      2874.397992
# 18    28.638900      2577.123015
# 19    25.824583      2149.504487
# 20    32.237058      3193.724993
# 21    22.789877      1648.852561
# 22    25.842893      2048.248603
# 23    27.327237      2280.523293
# 24    29.121400      2684.794050
# 25    35.703519      3992.035857
# 26    23.993476      1823.460114
# ...

# %%
#QUESTION 4:Simple Linear Regression with Outliers
import numpy as np
from sklearn.linear_model import RANSACRegressor, LinearRegression
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generate dataset with outliers
np.random.seed(42)


# Generate data without outliers
X = np.random.uniform(low=1, high=15, size=180)
Y = 1000*X + 5000 + np.random.normal(loc=0, scale=1000, size=180)


# Define your dataset
data = {
    'Years of Experience': X,
    'Salary': Y
}

df = pd.DataFrame(data)

# Set option to display all rows
pd.set_option('display.max_rows', None)

# Display all rows of the dataset
print(df)

# Introduce outliers
outlier_X = np.random.uniform(low=1, high=15, size=20)
outlier_Y = 1000*outlier_X + 5000 + np.random.normal(loc=0, scale=5000, size=20)

# Combine data with outliers
X = np.concatenate((X, outlier_X))
Y = np.concatenate((Y, outlier_Y))

# Standard Linear Regression
model = LinearRegression()
model.fit(X.reshape(-1, 1), Y)
Y_pred = model.predict(X.reshape(-1, 1))

# Robust Linear Regression using RANSAC
ransac = RANSACRegressor(LinearRegression())
ransac.fit(X.reshape(-1, 1), Y)
inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)
Y_pred_ransac = ransac.predict(X.reshape(-1, 1))

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(X, Y, color='blue', label='Data Points')
plt.plot(X, Y_pred, color='red', label='Standard Linear Regression')
plt.plot(X[inlier_mask], Y_pred_ransac[inlier_mask], color='green', label='Robust Linear Regression (RANSAC)')
plt.scatter(X[outlier_mask], Y[outlier_mask], color='orange', label='Outliers')
plt.title('Comparison of Standard vs. Robust Linear Regression')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()


print("""
INTERPRETATION 

The Standard Linear Regression model (red line) is heavily influenced by the outliers, leading to a suboptimal fit to the data.

In contrast, the Robust Linear Regression model using RANSAC (green line) provides a more reliable estimate of the underlying relationship between 'Years of Experience' and 'Salary' by downweighting the effect of outliers.

RANSAC helps in identifying the inliers and outliers in the dataset and fits the model using the inliers, resulting in a more robust regression line.""")

#NOTES
#This code will generate a custom dataset with outliers, apply both standard linear regression and robust linear regression (RANSAC), and plot the results for comparison. You can observe how the robust model handles outliers better compared to the standard linear regression model.
# Out:
#      Years of Experience        Salary
# 0               6.243562  10460.308372
# 1              14.310000  18987.938774
# 2              11.247915  17061.432403
# 3               9.381219  13150.354462
# 4               3.184261   8411.720901
# 5               3.183923   9491.066039
# 6               1.813171   5205.687336
# 7              13.126466  18311.099899
# 8               9.415610  14675.492959
# 9              10.913016  16694.838961
# 10              1.288183   5051.232209
# 11             14.578738  18258.281317
# 12             12.654197  18176.138537
# 13              3.972748   9269.732223
# 14              3.545550   8796.042391
# 15              3.567663   8914.111347
# 16              5.259391   9579.366680
# 17              8.346590  13578.843740
# 18              7.047230  12340.302734
# 19              5.077208   9362.856545
# 20              9.565941  16431.715037
# 21              2.952914   8426.746970
# 22              5.090025   8898.721582
# ...

# %%
#QUESTION 5:Multiple Linear Regression with Categorical Variables
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import OneHotEncoder

# Generate synthetic data
np.random.seed(42)
n_samples = 300

square_footage = np.random.randint(1000, 3000, n_samples)
num_bedrooms = np.random.randint(2, 6, n_samples)
neighborhoods = np.random.choice(['A', 'B', 'C'], n_samples)

# Create a DataFrame
data = pd.DataFrame({
    'SquareFootage': square_footage,
    'NumBedrooms': num_bedrooms,
    'Neighborhood': neighborhoods
})

# Display all rows of the dataset
pd.set_option('display.max_rows', None)
print(data)


# One-hot encode the categorical variable (Neighborhood)
data = pd.get_dummies(data, columns=['Neighborhood'])

# Generate house prices based on the features
data['HousePrice'] = 1000*data['SquareFootage'] + 5000*data['NumBedrooms'] + \
                     20000*data['Neighborhood_A'] + 15000*data['Neighborhood_B'] + 10000*data['Neighborhood_C'] + \
                     np.random.normal(0, 50000, n_samples)

# Split data into features and target variable
X = data.drop('HousePrice', axis=1)
y = data['HousePrice']

# Fit a Multiple Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Evaluate the model
r2 = r2_score(y, y_pred)
mse = mean_squared_error(y, y_pred)

print("R-squared:", r2)
print("Mean Squared Error:", mse)



# Plot actual vs. predicted house prices
plt.figure(figsize=(10, 6))
plt.scatter(range(len(y)), y, color='blue', label='Actual House Prices')
plt.scatter(range(len(y)), y_pred, color='red', label='Predicted House Prices')
plt.title('Actual vs. Predicted House Prices')
plt.xlabel('Sample Index')
plt.ylabel('House Price')
plt.legend()
plt.show()

print("""
INTERPRETATION OF RESULTS

R-squared:

The R-squared value is 0.9918, which indicates that approximately 99.18% of the variance in house prices is explained by the features included in the model.
This high R-squared value suggests that the model fits the data very well and can effectively predict house prices based on square footage, number of bedrooms, and neighborhood.
Mean Squared Error (MSE):

The Mean Squared Error is 2574079899.46.

MSE represents the average squared difference between the actual house prices and the predicted house prices.

In this case, the relatively low MSE indicates that the model's predictions are close to the actual house prices on average.

In summary, the high R-squared value and low MSE suggest that the Multiple Linear Regression model is performing very well in predicting house prices based on the provided features. The model explains a significant amount of the variance in house prices and makes accurate predictions with relatively small errors.""")


#NOTES
#We generate synthetic data for square footage, number of bedrooms, and neighborhood.
#One-hot encode the categorical variable (neighborhood).
#Create house prices based on the features.
#Fit a Multiple Linear Regression model to predict house prices.
#Evaluate the model's accuracy using R-squared and Mean Squared Error.
#You can further analyze the coefficients of the model to interpret the impact of each feature on the house prices. Feel free to adjust the data generation process and model parameters to explore different scenarios and improve the model's accuracy.
# Out:
#      SquareFootage  NumBedrooms Neighborhood
# 0             2126            5            C
# 1             2459            3            A
# 2             1860            5            B
# 3             2294            3            B
# 4             2130            5            B
# 5             2095            4            C
# 6             2724            5            A
# 7             2044            4            C
# 8             2638            4            C
# 9             1121            5            B
# 10            1466            4            C
# 11            2238            2            B
# 12            1330            4            A
# 13            2482            3            B
# 14            1087            5            A
# 15            2396            2            B
# 16            2123            5            C
# 17            1871            3            C
# 18            2687            3            A
# 19            1130            3            A
# ...

# %%
#Question 6:Non-Linear Trend in Stock Prices

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# Generate synthetic data for stock prices over time with a non-linear trend
np.random.seed(42)
n_samples = 300
time = np.linspace(1, 10, n_samples)
stock_prices = 100 + 2*time**2 + np.random.normal(0, 10, n_samples)

# Reshape the data
X = time.reshape(-1, 1)
y = stock_prices

# Create a DataFrame with the stock price data
stock_data = pd.DataFrame({'Time': time, 'Stock Price': stock_prices})

# Display all rows of the dataset
pd.set_option('display.max_rows', None)
print(stock_data)

# Apply polynomial regression with different degrees
degrees = [1, 2, 3, 4, 5]
mse_scores = []

plt.figure(figsize=(12, 8))
plt.scatter(time, stock_prices, color='blue', label='Actual Stock Prices')

for degree in degrees:
    poly_features = PolynomialFeatures(degree=degree)
    X_poly = poly_features.fit_transform(X)
    
    model = LinearRegression()
    model.fit(X_poly, y)
    y_pred = model.predict(X_poly)
    
    mse = mean_squared_error(y, y_pred)
    mse_scores.append(mse)
    
    plt.plot(time, y_pred, label=f'Degree {degree} (MSE: {mse:.2f})')

plt.title('Polynomial Regression for Stock Prices')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# Analyze the performance of different polynomial degrees
for degree, mse in zip(degrees, mse_scores):
    print(f'Degree {degree} - Mean Squared Error: {mse:.2f}')
    

print("INTERPRETATION")
    
print("Degree 1: The model with a linear relationship (degree 1) has an MSE of 232.38. This means that, on average, the squared difference between the predicted values and actual values is 232.38.")    
print("Degree 2: The model with a quadratic relationship (degree 2) has a lower MSE of 95.96, indicating a better fit compared to the linear model.")
print("Degree 3, Degree 4, Degree 5: As the degree of the polynomial increases, the MSE values continue to decrease, reaching a minimum at degree 4 and degree 5.")


#Model Selection:In this case, a polynomial model of degree 4 or 5 seems to provide the best fit to the data based on the MSE values. These models have lower errors compared to lower-degree polynomials.
#However, it is important to balance model complexity with performance, as higher-degree polynomials may lead to overfitting if the model captures noise in the data rather than true patterns.

#NOTES
#We generate synthetic data for stock prices over time with a non-linear trend.
#We apply polynomial regression with degrees ranging from 1 to 5 to capture the non-linear trends.
#We evaluate the performance of each polynomial degree by calculating the Mean Squared Error (MSE) and visualize the predicted stock prices.
#You can analyze the MSE values for each polynomial degree to understand how well the model fits the data. Higher degrees may lead to overfitting, while lower degrees may underfit the data. This analysis can help you choose an appropriate polynomial degree for predicting future stock prices based on the observed non-linear trend.
# Out:
#           Time  Stock Price
# 0     1.000000   106.967142
# 1     1.030100   100.739570
# 2     1.060201   108.724936
# 3     1.090301   117.607811
# 4     1.120401   100.169065
# 5     1.150502   100.305939
# 6     1.180602   118.579770
# 7     1.210702   110.605948
# 8     1.240803    98.384439
# 9     1.270903   108.655989
# 10    1.301003    98.751042
# 11    1.331104    98.886376
# 12    1.361204   106.125375
# 13    1.391304    84.738653
# 14    1.421405    86.791604
# 15    1.451505    98.590858
# 16    1.481605    94.261998
# 17    1.511706   107.712981
# 18    1.541806    95.674091
# 19    1.571906    90.818742
# 20    1.602007   119.789339
# 21    1.632107   103.069784
# 22    1.662207   106.201149
# 23    1.692308    91.480329
# 24    1.722408   100.489552
# 25    1.752508   107.251797
# 26    1.782609    94.845452
# 27    1.812709   110.328808
# 28    1.842809   100.785506
# 29    1.872910   104.098644
# 30    1.903010   101.225828
# 31    1.933110   125.996613
# ...

# %%
#Question 7:Time Series Analysis

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Generate synthetic data for monthly sales of a product over time
np.random.seed(42)
n_months = 400
months = pd.date_range(start='1/1/2010', periods=n_months, freq='M')
sales = 100 + 2*np.arange(n_months) + np.random.normal(0, 20, n_months)

# Create a DataFrame with the monthly sales data
sales_data = pd.DataFrame({'Month': months, 'Sales': sales})

# Display all rows of the dataset
pd.set_option('display.max_rows', None)
print(sales_data)


# Implement a linear regression model to predict future sales
X = np.arange(n_months).reshape(-1, 1)
y = sales

model = LinearRegression()
model.fit(X, y)

# Predict future sales for the next 12 months
future_months = pd.date_range(start='1/1/2024', periods=12, freq='M')
future_X = np.arange(n_months, n_months + 12).reshape(-1, 1)
future_sales_pred = model.predict(future_X)

# Evaluate the model's accuracy
y_pred = model.predict(X)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)

print(f'Root Mean Squared Error: {rmse:.2f}')

# Plot actual sales data and predicted future sales
plt.figure(figsize=(12, 6))
plt.plot(months, sales, label='Actual Sales')
plt.plot(np.append(months, future_months), np.append(sales, future_sales_pred), linestyle='--', label='Predicted Sales')
plt.title('Monthly Sales Prediction with Linear Regression')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.show()

# Discuss limitations in time series forecasting using regression
print('Limitations in time series forecasting using regression:')
print('- Linear regression assumes a linear relationship between the features and the target variable.')
print('- It may not capture complex patterns or seasonality present in the time series data.')

#We generate synthetic data for monthly sales of a product over time.
#We implement a linear regression model to predict future sales based on historical data.
#We evaluate the model's accuracy using Root Mean Squared Error (RMSE) and plot the actual sales data along with the predicted future sales.
#We discuss limitations in time series forecasting using regression, such as the assumption of linearity and the inability to capture complex patterns or seasonality.
# Out:
#          Month       Sales
# 0   2010-01-31  109.934283
# 1   2010-02-28   99.234714
# 2   2010-03-31  116.953771
# 3   2010-04-30  136.460597
# 4   2010-05-31  103.316933
# 5   2010-06-30  105.317261
# 6   2010-07-31  143.584256
# 7   2010-08-31  129.348695
# 8   2010-09-30  106.610512
# 9   2010-10-31  128.851201
# 10  2010-11-30  110.731646
# 11  2010-12-31  112.685405
# 12  2011-01-31  128.839245
# 13  2011-02-28   87.734395
# 14  2011-03-31   93.501643
# 15  2011-04-30  118.754249
# 16  2011-05-31  111.743378
# 17  2011-06-30  140.284947
# 18  2011-07-31  117.839518
# 19  2011-08-31  109.753926
# 20  2011-09-30  169.312975
# 21  2011-10-31  137.484474
# 22  2011-11-30  145.350564
# 23  2011-12-31  117.505036
# 24  2012-01-31  137.112346
# 25  2012-02-29  152.218452
# 26  2012-03-31  128.980128
# 27  2012-04-30  161.513960
# 28  2012-05-31  143.987226
# 29  2012-06-30  152.166125
# 30  2012-07-31  147.965868
# 31  2012-08-31  199.045564
# 32  2012-09-30  163.730056
# ...

# %%
#Question 8: Multiple Regression,  Predicting Car Prices 
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Generate synthetic data for predicting car prices
np.random.seed(42)
n_cars = 500
horsepower = np.random.randint(100, 400, n_cars)
fuel_efficiency = np.random.uniform(15, 40, n_cars)
brand_reputation = np.random.uniform(1, 10, n_cars)
noise = np.random.normal(0, 5000, n_cars)
car_prices = 20000 + 100*horsepower + 500*(-fuel_efficiency) + 2000*brand_reputation + noise

# Create a DataFrame with the car price and features data
car_data = pd.DataFrame({'Horsepower': horsepower, 'Fuel Efficiency': fuel_efficiency, 'Brand Reputation': brand_reputation, 'Price': car_prices})

# Display all rows of the dataset
pd.set_option('display.max_rows', None)
print(car_data)


# Implement a multiple regression model to predict car prices
X = car_data[['Horsepower', 'Fuel Efficiency', 'Brand Reputation']]
y = car_data['Price']

model = LinearRegression()
model.fit(X, y)

# Evaluate the model's performance
y_pred = model.predict(X)
mse = mean_squared_error(y, y_pred)

print(f'Mean Squared Error: {mse:.2f}')

# Discuss the impact of each feature on the predicted car prices
coefficients = model.coef_
intercept = model.intercept_

print('Impact of each feature on predicted car prices:')
print(f'- Horsepower: {coefficients[0]:.2f}')
print(f'- Fuel Efficiency: {coefficients[1]:.2f}')
print(f'- Brand Reputation: {coefficients[2]:.2f}')
print(f'Intercept: {intercept:.2f}')

import matplotlib.pyplot as plt

# Plot actual car prices vs. predicted car prices
plt.figure(figsize=(10, 6))
plt.scatter(y, y_pred, color='blue', label='Actual vs. Predicted Prices')
plt.plot([min(y), max(y)], [min(y), max(y)], color='red', linestyle='--', label='Perfect Fit Line')
plt.title('Actual vs. Predicted Car Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()

print("""

INTERPREATION OF RESULTS

Mean Squared Error (MSE):

The Mean Squared Error of the model is $24393557.34. This value represents the average squared difference between the actual car prices and the predicted car prices. A lower MSE indicates better model performance.

Impact of Each Feature:

Horsepower: For every unit increase in horsepower, the predicted car price is expected to increase by $104.24, all else being equal.
Fuel Efficiency: For every unit decrease in fuel efficiency, the predicted car price is expected to decrease by $563.23, all else being equal.
Brand Reputation: For every unit increase in brand reputation, the predicted car price is expected to increase by $1981.00, all else being equal.

Intercept:

The intercept of the model is $20673.62. This represents the baseline price of a car when all features (Horsepower, Fuel Efficiency, Brand Reputation) are zero.
These results provide insights into how each feature impacts the predicted car prices. Horsepower has a positive impact on price, fuel efficiency has a negative impact, and brand reputation has a significant positive impact. The intercept represents the base price of a car without considering any features.""")

#NOTES
#We generate synthetic data for predicting car prices based on features like horsepower, fuel efficiency, and brand reputation.
#We build a multiple regression model to predict car prices using these features.
#We evaluate the model's performance using Mean Squared Error (MSE).
#We discuss the impact of each feature on the predicted car prices by analyzing the coefficients of the regression model. Positive coefficients indicate a positive impact on car prices, while negative coefficients indicate a negative impact.
#You can further analyze the model's performance, visualize the predictions, and explore the relationships between the features and the predicted car prices to gain insights into the factors influencing car prices.
# Out:
#      Horsepower  Fuel Efficiency  Brand Reputation         Price
# 0           202        34.037766          8.514372  29705.267059
# 1           370        30.455452          9.859620  76180.277697
# 2           206        17.528067          5.731212  38942.721010
# 3           171        17.102670          2.545114  35655.842186
# 4           288        32.524228          3.450766  34747.078183
# 5           120        16.819075          1.165516  29142.835396
# 6           202        35.546501          9.228689  42266.973540
# 7           221        32.656056          2.059760  26637.923966
# 8           314        17.033720          6.188648  60625.873528
# 9           187        17.120943          3.466497  36252.718148
# 10          199        39.665989          5.987602  34778.289004
# 11          251        24.356770          6.862783  42061.383017
# 12          230        24.266054          8.467676  47647.887451
# ...

# %%
#Question 9:Polynomial Regression, Population Growth 

import numpy as np
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Generate synthetic data for modeling population growth
np.random.seed(42)
years = np.arange(1, 51)
population_growth = 1000 + 50*years + 2*years**2 + np.random.normal(0, 500, 50)

# Create a DataFrame with the population growth data
population_data = pd.DataFrame({'Year': years, 'Population': population_growth})

# Display all rows of the dataset
pd.set_option('display.max_rows', None)
print(population_data)

# Implement a polynomial regression model to capture changing growth patterns
X = population_data['Year'].values.reshape(-1, 1)
y = population_data['Population'].values

# Choose the polynomial degree (e.g., degree=2)
poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)

# Predict future population sizes
future_years = np.arange(51, 61)
X_future = future_years.reshape(-1, 1)
X_future_poly = poly_features.transform(X_future)
future_population = model.predict(X_future_poly)

# Plot the actual population growth data and the predicted growth trends
plt.figure(figsize=(10, 6))
plt.scatter(years, population_growth, color='blue', label='Actual Population Growth')
plt.plot(future_years, future_population, color='red', linestyle='--', label='Predicted Growth Trend')
plt.title('Population Growth Over the Years')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()

# Discuss the choice of polynomial degree and its implications
print(f'Chosen Polynomial Degree: {poly_features.degree}')

print("""
INTERPRETATION OF RESULTS

Polynomial Degree: 2 indicates that in the context of polynomial regression, a polynomial of degree 2 has been selected as the model to fit the data.

Implications:

Model Complexity: polynomial degree of 2 implies that the model will have a quadratic relationship between the independent variable(s) and the dependent variable. This means that the model will capture both linear and quadratic trends in the data.

Flexibility vs. Overfitting: A polynomial of degree 2 strikes a balance between model complexity and overfitting. Higher-degree polynomials can lead to overfitting, capturing noise in the data instead of the underlying patterns. A degree of 2 is often chosen when there is a need to capture some non-linear patterns without introducing excessive complexity.

Interpretability: With a polynomial degree of 2, the model is still relatively interpretable compared to higher-degree polynomials. The coefficients of the quadratic terms can provide insights into the curvature of the relationship between the variables.

Model Performance: polynomial degree 2 suggests that the model aims to capture both linear and quadratic relationships in the data. The performance of the model will depend on how well these polynomial features represent the underlying data patterns.

Trade-off: Choosing the degree of the polynomial involves a trade-off between bias and variance. A degree of 2 balances capturing non-linear relationships with avoiding excessive complexity, which can lead to poor generalization on new data.")
""")

#NOTES
#We generate synthetic data for modeling population growth over the years with a quadratic growth pattern.
#We implement a polynomial regression model with a chosen degree (e.g., degree=2) to capture the changing growth patterns.
#We predict future population sizes using the polynomial regression model.
#We plot the actual population growth data and the predicted growth trends to visualize the model's performance.
#We discuss the choice of polynomial degree and its implications for predicting future population sizes.
# Out:
#     Year   Population
# 0      1  1300.357077
# 1      2  1038.867849
# 2      3  1491.844269
# 3      4  1993.514928
# 4      5  1182.923313
# 5      6  1254.931522
# 6      7  2237.606408
# 7      8  1911.717365
# 8      9  1377.262807
# 9     10  1971.280022
# 10    11  1560.291154
# 11    12  1655.135123
# 12    13  2108.981136
# 13    14  1135.359878
# 14    15  1337.541084
# 15    16  2030.856235
# 16    17  1921.584440
# 17    18  2705.123666
# 18    19  2217.987962
# 19    20  2093.848149
# 20    21  3664.824384
# 21    22  2955.111850
# 22    23  3241.764102
# 23    24  2639.625907
# 24    25  3227.808638
# 25    26  3707.461295
# 26    27  3232.503211
# 27    28  4155.849009
# 28    29  3831.680655
# 29    30  4154.153125
# 30    31  4171.146694
# 31    32  5574.139092
# 32    33  4821.251388
# 33    34  4483.144536
# 34    35  5611.272456
# 35    36  4781.578175
# 36    37  5692.431798
# 37    38  4808.164938
# 38    39  5327.906976
# 39    40  6298.430618
# ...

# %%
#Question 10:Simple Linear Regression with Missing Values 

import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Generate synthetic data for Simple Linear Regression
np.random.seed(42)
miles_commute = np.random.uniform(5, 30, 500)
public_transport_usage = 50 - 1.5*miles_commute + np.random.normal(0, 5, 500)

# Introduce missing values in the dataset
missing_indices = np.random.choice(range(500), size=50, replace=False)
public_transport_usage[missing_indices] = np.nan

# Create a DataFrame with the dataset
data = pd.DataFrame({'Miles_Commute': miles_commute, 'Public_Transport_Usage': public_transport_usage})

# Display all rows of the dataset
pd.set_option('display.max_rows', None)
print(data)

# Handle missing values using mean imputation
data['Public_Transport_Usage'].fillna(data['Public_Transport_Usage'].mean(), inplace=True)

# Apply Linear Regression model
X = data['Miles_Commute'].values.reshape(-1, 1)
y = data['Public_Transport_Usage'].values

model = LinearRegression()
model.fit(X, y)

# Assess predictive performance
r_squared = model.score(X, y)
print(f'R-squared: {r_squared}')

print("In this case, an R-squared value of 0.7410523077479565 indicates that approximately 74.11% of the variance in the dependent variable (y) can be explained by the independent variable(s) (X) in the regression model. This means that the model is able to account for 74.11% of the variability in the observed data points.A higher R-squared value closer to 1 indicates a better fit of the model to the data, while a lower R-squared value closer to 0 suggests that the model does not explain much of the variability in the data.")
# Plot the data and the linear regression line
plt.figure(figsize=(10, 6))
plt.scatter(miles_commute, public_transport_usage, color='blue', label='Data with Missing Values')
plt.plot(miles_commute, model.predict(X), color='red', label='Linear Regression Line')
plt.title('Relationship between Miles Commute and Public Transport Usage')
plt.xlabel('Miles Commute to Work')
plt.ylabel('Public Transport Usage')
plt.legend()
plt.grid(True)
plt.show()

#NOTES
#We generate synthetic data for Simple Linear Regression between the number of miles people commute to work and the frequency of public transportation usage.
#We introduce missing values in the dataset to simulate real-world scenarios.
#We handle missing values using mean imputation to fill in the missing values in the 'Public_Transport_Usage' column.
#We apply a Linear Regression model to predict public transportation usage based on the number of miles people commute to work.
#We assess the predictive performance of the model by calculating the R-squared value.
#We plot the data points with missing values and the linear regression line to visualize the relationship between miles commuted and public transport usage.
# Out:
#      Miles_Commute  Public_Transport_Usage
# 0        14.363503               30.163525
# 1        28.767858               16.229068
# 2        23.299849               19.802346
# 3        19.966462               17.165789
# 4         8.900466               32.157228
# 5         8.899863               39.109801
# 6         6.452090               33.720699
# 7        26.654404               19.175688
# 8        20.027875               25.855388
# 9        22.701814               13.601400
# 10        5.514612               33.162409
# 11       29.247746               12.897742
# 12       25.811066               10.710702
# 13       10.308478               40.726365
# 14        9.545624               27.709425
# 15        9.585113                     NaN
# 16       12.606056               31.117134
# 17       18.118911               23.056537
# 18       15.798625                     NaN
# 19       12.280729               34.693157
# 20       20.296322               14.217414
# ...
